# %% [markdown]
# ## 원천데이터 전처리

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_excel('Source_data/감성대화말뭉치(Training).xlsx')
valid = pd.read_excel('Source_data/감성대화말뭉치(Validation).xlsx')

train.head()
# Out:
#       번호   연령  성별       상황키워드    신체질환 감정_대분류   감정_소분류  \
# 0  44164   청년  남성  연애, 결혼, 출산    해당없음     기쁨     신이 난
# 1   3926   노년  남성      건강, 죽음  만성질환 유     불안  스트레스 받는
# 2  50882  청소년  여성     학업 및 진로    해당없음     당황       당황
# 3  31303   노년  남성          재정  만성질환 무     기쁨     신이 난
# 4  47200   노년  여성          재정  만성질환 유     기쁨       안도
#
#                                            사람문장1  \
# 0                      아내가 드디어 출산하게 되어서 정말 신이 나.
# 1        당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.
# 2        고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.
# 3  재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 4                   빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
#
#                                     시스템응답1  \
# 0                아내분이 출산을 하시는군요. 정말 축하드려요.
# 1                       약 종류가 많아 번거로우시겠어요.
# 2  고등학교 수업이 중학교 때와는 다르게 갑자기 어려워서 당황스러우시군요.
# 3                  재취업 후 첫 월급이라 정말 기쁘시겠어요.
# 4           기분 좋으시겠어요. 앞으로는 어떻게 하실 생각이신가요?
#
#                                                사람문장2  \
# ...

# %%
train = train.iloc[:, 7:]
valid = valid.iloc[:, 7:]

valid.head()
# Out:
#                                               사람문장1  \
# 0                                   요즘 부모님과 많이 부딪혀.
# 1                          엄마가 결국 집을 나갔어. 너무 너무 슬퍼.
# 2                    학교에서 한 친구를 괴롭히는 무리에게 그만하라고 했어.
# 3  이번에 팀장님이 간단한 조사 업무를 부탁하셨는데 내가 잘못 처리했어. 너무 절망적이야.
# 4                 남편이 이혼할 때 위자료를 주지 않으려고 변호사를 고용했어.
#
#                                         시스템응답1  \
# 0                                어떤 일로 부딪히시나요?
# 1  어머니께서 집을 나가셨다니 정말 슬프셨겠어요. 좀 더 자세히 얘기해주시겠어요?
# 2                   용기 있는 행동을 하셨네요. 마음이 어떠셨나요?
# 3      팀장님이 부탁하신 업무를 잘못 처리하셔서 많이 당황하시고 놀라셨겠어요.
# 4                                 많이 화가 나시겠어요.
#
#                                                사람문장2  \
# 0  난 하고 싶은 일이 있는데 부모님은 안정적인 일만 하라고 하셔. 내 마음대로 하지도...
# 1  엄마도 엄마만의 인생이 있을 테니 가지 말라고 할 수가 없었어. 그래서 더 마음이 ...
# 2                      그런데 말을 하고 난 후 나도 괴롭힐까 봐 불안했어.
# 3               곧 있으면 인턴에서 정규직 전환 평가가 있는데 안 좋을 것 같아.
# 4                             어떻게 그럴 수가 있지? 너무 화가 나.
#
# ...

# %%
train_1 = train.iloc[:, :2]
train_2 = train.iloc[:, 2:4]
train_3 = train.iloc[:, 4:6]
train_4 = train.iloc[:, 6:8]

valid_1 = valid.iloc[:, :2]
valid_2 = valid.iloc[:, 2:4]
valid_3 = valid.iloc[:, 4:6]
valid_4 = valid.iloc[:, 6:8]

train_1.columns = ["Q", "A"]
train_2.columns = ["Q", "A"]
train_3.columns = ["Q", "A"]
train_4.columns = ["Q", "A"]

valid_1.columns = ["Q", "A"]
valid_2.columns = ["Q", "A"]
valid_3.columns = ["Q", "A"]
valid_4.columns = ["Q", "A"]

valid_1.head()
# Out:
#                                                   Q  \
# 0                                   요즘 부모님과 많이 부딪혀.
# 1                          엄마가 결국 집을 나갔어. 너무 너무 슬퍼.
# 2                    학교에서 한 친구를 괴롭히는 무리에게 그만하라고 했어.
# 3  이번에 팀장님이 간단한 조사 업무를 부탁하셨는데 내가 잘못 처리했어. 너무 절망적이야.
# 4                 남편이 이혼할 때 위자료를 주지 않으려고 변호사를 고용했어.
#
#                                              A
# 0                                어떤 일로 부딪히시나요?
# 1  어머니께서 집을 나가셨다니 정말 슬프셨겠어요. 좀 더 자세히 얘기해주시겠어요?
# 2                   용기 있는 행동을 하셨네요. 마음이 어떠셨나요?
# 3      팀장님이 부탁하신 업무를 잘못 처리하셔서 많이 당황하시고 놀라셨겠어요.
# 4                                 많이 화가 나시겠어요.

# %%
data = pd.concat([train_1, train_2, train_3, train_4, 
                  valid_1, valid_2, valid_3, valid_4], axis=0)

print("Data's Length :", len(data))
data.head()
# Out:
# Data's Length : 184036
#                                                Q  \
# 0                      아내가 드디어 출산하게 되어서 정말 신이 나.
# 1        당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.
# 2        고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.
# 3  재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 4                   빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
#
#                                          A
# 0                아내분이 출산을 하시는군요. 정말 축하드려요.
# 1                       약 종류가 많아 번거로우시겠어요.
# 2  고등학교 수업이 중학교 때와는 다르게 갑자기 어려워서 당황스러우시군요.
# 3                  재취업 후 첫 월급이라 정말 기쁘시겠어요.
# 4           기분 좋으시겠어요. 앞으로는 어떻게 하실 생각이신가요?

# %%
data = data.dropna()

len(data)
# Out:
# 128447

# %%
data.notnull().sum()
# Out:
# Q    128447
# A    128447
# dtype: int64

# %%
data.to_csv('QA_data.csv', index=False)

# %% [markdown]
# ## Embedding vector 구하기
# + npy 파일로 저장
# + model : https://huggingface.co/jhgan/ko-sroberta-multitask

# %%
import time
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer

# %%
data = pd.read_csv('QA_data.csv')
model = SentenceTransformer('jhgan/ko-sroberta-multitask')

# %%
data.shape
# Out:
# (127036, 2)

# %%
embed_768 = model.encode(data['Q'])

print(embed_768.shape)
print(type(embed_768))
# Out:
# (127036, 768)
# <class 'numpy.ndarray'>

# %%
np.save('embed_768.npy', embed_768)

# %%
embed = np.load('embed_768.npy')

embed.shape
# Out:
# (127036, 768)

# %% [markdown]
# ## TEST

# %%
data = pd.read_csv('QA_data.csv')
model = SentenceTransformer('jhgan/ko-sroberta-multitask')

# %%
a = model.encode(data.iloc[:10,0])
a.shape
# Out:
# (10, 768)

# %%
embed = pd.read_csv('embed_768.csv')
embed_arr = embed.to_numpy()

# %%
a[0]
# Out:
# array([-4.58952338e-01, -1.65475830e-01, -1.16999459e+00, -5.23581147e-01,
#         6.83547184e-02, -1.33704454e-01,  2.92058319e-01, -2.52802402e-01,
#        -9.53772515e-02, -8.38730037e-01,  5.42452753e-01, -1.65980875e-01,
#        -6.91887915e-01,  7.94255853e-01, -9.43957508e-01, -6.27517462e-01,
#         4.37359273e-01,  6.75986946e-01, -5.40877044e-01, -5.64558566e-01,
#        -2.99055967e-03,  6.71547353e-02, -1.08207449e-01, -2.11772062e-02,
#         1.15095705e-01, -3.29754114e-01, -3.89416158e-01, -1.94628790e-01,
#        -2.79099643e-01,  6.35069966e-01,  5.88654637e-01, -6.88186407e-01,
#        -3.25743705e-01, -2.39707530e-01,  7.80149922e-02, -3.85961048e-02,
#        -9.85636830e-01,  2.01991528e-01, -8.84459615e-01, -2.94946469e-02,
#         4.17395473e-01,  3.98282349e-01,  2.68196493e-01,  5.29761314e-01,
#        -7.28141248e-01, -3.61298084e-01,  8.46633911e-01, -1.09494627e-02,
# ...

# %%
embed_arr[0]
# Out:
# array([-4.58951890e-01, -1.65475756e-01, -1.16999495e+00, -5.23580909e-01,
#         6.83548599e-02, -1.33704484e-01,  2.92058915e-01, -2.52802432e-01,
#        -9.53770205e-02, -8.38730216e-01,  5.42452395e-01, -1.65980831e-01,
#        -6.91887915e-01,  7.94256210e-01, -9.43957508e-01, -6.27517521e-01,
#         4.37359512e-01,  6.75986588e-01, -5.40877283e-01, -5.64558983e-01,
#        -2.99028307e-03,  6.71543777e-02, -1.08207531e-01, -2.11770236e-02,
#         1.15095831e-01, -3.29753757e-01, -3.89416277e-01, -1.94628909e-01,
#        -2.79099792e-01,  6.35069966e-01,  5.88654160e-01, -6.88185930e-01,
#        -3.25743616e-01, -2.39708155e-01,  7.80151486e-02, -3.85959409e-02,
#        -9.85636890e-01,  2.01991409e-01, -8.84459555e-01, -2.94943266e-02,
#         4.17395532e-01,  3.98282319e-01,  2.68196821e-01,  5.29761016e-01,
#        -7.28141427e-01, -3.61297905e-01,  8.46634448e-01, -1.09498017e-02,
# ...

# %%
import torch
import torch.nn as nn

m = nn.CosineSimilarity(dim=-1)

# %%
i1 = torch.tensor(a[2]).float()
i2 = torch.tensor(embed_arr[5]).float()

# %%
m(i1, i2)
# Out:
# tensor(0.2299)
